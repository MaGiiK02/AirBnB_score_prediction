# %%
# !pip install transformers
# !pip install sentence-transformers
# %clear
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import os
import torch
import torch.nn as nn

from transformers import BertTokenizer, BertModel, AutoTokenizer
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split

import pickle

# %%
# Mount Drive
from google.colab import drive
MOUNT_PATH = '/content/drive/'
drive.mount(MOUNT_PATH)

import sys
PROJECT_PATH = 'MyDrive/UCY/NLP/AirBnB project'
EFFECTIVE_PROJECT_PATH = f'{MOUNT_PATH}{PROJECT_PATH}'
DATASET_PATH = f'{EFFECTIVE_PROJECT_PATH}/Dataset'
VISUALIZATION_PATH = f'{EFFECTIVE_PROJECT_PATH}/visualization'

sys.path.append(EFFECTIVE_PROJECT_PATH)
sys.path.append(DATASET_PATH)
sys.path.append(VISUALIZATION_PATH)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/UCY/NLP/AirBnB project/listings_comments.csv')

# %%
# load comments embeddings
with open('/content/drive/MyDrive/UCY/NLP/AirBnB project/comments_embeddings.pkl', 'rb') as f:
    comments_embeddings = pickle.load(f)

# %%
comments_embeddings.shape
# Out:
# (6998, 384)

# %%
# pd.set_option('display.max_colwidth', None)
df.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'source',
#        'name', 'description', 'neighborhood_overview', 'picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
label  = df['review_scores_rating'].values

# %%
# from embedding.py load the function visualize_3D
from visualization.embedding import * 
# C:\Users\Kyriakos\Desktop\MsC AI\NLP\NLP AirBNB Project\AirBnB_score_prediction\visualization\embedding.py

# %%
# this will take a while in colab
reduced_vectors, model = reduce_dimensionality(comments_embeddings, method='tSNE', method_settings={"perplexity":30.0, "random_state":0})

# %%
# from embeddings use the visualize_3D function to visualize the embeddings
visualize_3D(reduced_vectors, label, title="Comments embeddings")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
visualize_2D(reduced_vectors, label, title="Comments embeddings in 2D")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Embeddings results
# We see that there are a lot of positive reviews (yellows and light-green)
# From the visualizations We see that the black and some bold-green embeddings are on the outsite area(3D)
