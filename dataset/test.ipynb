# %%
from dataloader import Dataloader
data = Dataloader()
# Aproach 1 only listing data 
# Aproach 2 only reviews (Advanced analysis)
# Aproach 3 comninede

# Develop clustering o present vocabulary to express the different dimension (clean, communication checkin, value)
# Use bucket of 0-1 1-2 2-3 3-4 4-5
# 1 model for each dimension 

# Test more cities

# %%
conlumns = list(filter(lambda c: 'review' in c , data.getListings().columns))
data.getListings().sample(3)[conlumns]
data.getListings().sample(3)
# Out:
#             id                            listing_url       scrape_id  \
# 354    2981875   https://www.airbnb.com/rooms/2981875  20221205143541
# 1552  15213109  https://www.airbnb.com/rooms/15213109  20221205143541
# 1996  19303386  https://www.airbnb.com/rooms/19303386  20221205143541
#
#      last_scraped           source  \
# 354    2022-12-05      city scrape
# 1552   2022-12-05      city scrape
# 1996   2022-12-05  previous scrape
#
#                                                 name  \
# 354     Hotel Not Hotel Amsterdam: Secret Bookcase L
# 1552  Light & spacious apartment near Jordaan/center
# 1996    Beautiful canal penthouse with roof terrace!
#
#                                             description  \
# 354   <b>The space</b><br />These are the most hidde...
# 1552  Completely renovated apartment in the trendy a...
# 1996  Most beautiful and luxury (but also very cosy)...
#
#                                   neighborhood_overview  \
# 354   Traditionally a blue collar neighbourhood just...
# 1552  This neighbourhood has everything to offer wit...
# 1996                                                NaN
#
#                                             picture_url   host_id  ...  \
# 354   https://a0.muscache.com/pictures/miso/Hosting-...  14574533  ...
# 1552  https://a0.muscache.com/pictures/1d46a251-eea3...   2574458  ...
# 1996  https://a0.muscache.com/pictures/d33e66b8-5e6a...  99355470  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 354                         4.75                   4.33                4.21
# 1552                        4.91                   4.68                4.58
# 1996                        4.86                   4.95                4.81
#
#                        license instant_bookable  \
# 354                     Exempt                t
# 1552  0363 F335 F4F3 9D92 B493                f
# 1996  0363 84B7 46B2 7974 5F12                f
#
#      calculated_host_listings_count  \
# 354                              20
# 1552                              1
# 1996                              3
#
#      calculated_host_listings_count_entire_homes  \
# 354                                            0
# 1552                                           1
# 1996                                           3
#
#      calculated_host_listings_count_private_rooms  \
# 354                                            20
# 1552                                            0
# 1996                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 354                                            0              0.43
# 1552                                           0              0.77
# 1996                                           0              0.32
#
# [3 rows x 75 columns]

# %%
data.getComments().sample(3)
# Out:
#         listing_id                  id        date  reviewer_id reviewer_name  \
# 270928    32624969  676594809152110256  2022-07-22     19977724        Monica
# 154727    11857316  591074816684525017  2022-03-26     59862858        Hannah
# 255424    29175007  770131479309832777  2022-11-28     35572145        Lahari
#
#                                                  comments
# 270928  Super location, the rooms were small but cool ...
# 154727  Lovely boathouse in ideal location, convenient...
# 255424  We had a wonderful stay at Semira and Jack's. ...

# %%
# Comments from listing
listings = data.getListings()[data.getListings()['id'] == 32707589]
filtered_comments = data.getCommentsFromListing(listings)  # or data.getCommentsFromListing(32707589) 
filtered_comments.sample(3)
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 271630    32707589  511502563  2019-08-17    102573373    ElHoussein
# 271717    32707589  597810083  2020-01-26     29150003        Oliver
# 271719    32707589  604090986  2020-02-10    167452385        Oliver
#
#                                                  comments
# 271630  Great place, great host, amazing location in t...
# 271717  Beautiful apartment in a lovely area, near to ...
# 271719  Amazing location, in the heart of Amsterdam, t...

# %%
# more than 1 listing
listings = data.getListings().sample(3)
filtered_comments = data.getCommentsFromListing(listings) 
filtered_comments.sample(3)
# Out:
#         listing_id                  id        date  reviewer_id reviewer_name  \
# 104440     5748017           433363234  2019-04-06    236117358   Pierre-Yves
# 290869    40646054  486054740948133355  2021-11-01    426246824           Eda
# 290870    40646054  601908920045880721  2022-04-10     27965338        Moritz
#
#                                                  comments
# 104440   Perfect place to stay after long walks downtown.
# 290869  We spent 4 nights in the apartment and it was ...
# 290870                                         Nice host!

# %%
# Single comments 
comments = data.getComments()[data.getComments()['id'] == 466296625]['listing_id']

filtered_listing =  data.getListings()[data.getListings()['id'].isin(comments) ]
#filtered_listing = data.getListingByComments(comments) # or data.getListingByComments(466296625) 
filtered_listing
# Out:
#             id                            listing_url       scrape_id  \
# 3159  32707589  https://www.airbnb.com/rooms/32707589  20221205143541
#
#      last_scraped       source  \
# 3159   2022-12-05  city scrape
#
#                                                    name  \
# 3159  Spacious 4p apt at the best location you can get!
#
#                                             description neighborhood_overview  \
# 3159  Great spacious apartment on the most famous ca...                   NaN
#
#                                             picture_url    host_id  ...  \
# 3159  https://a0.muscache.com/pictures/7798ffc5-adfa...  245938143  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 3159                        4.94                   4.95                4.62
#
#                        license instant_bookable  \
# 3159  0363 6EF3 971C B15C C2FC                t
#
#      calculated_host_listings_count  \
# 3159                              1
#
#      calculated_host_listings_count_entire_homes  \
# 3159                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 3159                                            1
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 3159                                           0              1.47
#
# [1 rows x 75 columns]

# %%
# More than 1 comment 
comments = data.getComments().sample(3)
filtered_listing = data.getListingByComments(comments) # or data.getListingByComments([id1, id2]) 
filtered_listing.sample(2)
# Out:
#            id                           listing_url       scrape_id  \
# 6798   775655   https://www.airbnb.com/rooms/775655  20221205143541
# 829   7007415  https://www.airbnb.com/rooms/7007415  20221205143541
#
#      last_scraped           source                                 name  \
# 6798   2022-12-05      city scrape  the Boathouse bed&bike A'dam centre
# 829    2022-12-05  previous scrape  Cosy light apartment @ Amstel River
#
#                                             description  \
# 6798  <b>The space</b><br />Appartment comprises Roo...
# 829   Comfortable, well attained and very light apar...
#
#                                   neighborhood_overview  \
# 6798                                                NaN
# 829   The neighbourhood is near the Amstel, so green...
#
#                                             picture_url  host_id  ...  \
# 6798  https://a0.muscache.com/pictures/11535248/433c...  4091515  ...
# 829   https://a0.muscache.com/pictures/bc95968d-9545...  3441513  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 6798                        4.76                   4.93                4.53
# 829                         5.00                   4.68                4.62
#
#                        license instant_bookable  \
# 6798  0363 E246 20B0 E608 BF76                t
# 829   0363 A83E 119F AC97 4730                f
#
#      calculated_host_listings_count  \
# 6798                              2
# 829                               1
#
#      calculated_host_listings_count_entire_homes  \
# 6798                                           0
# 829                                            1
#
#      calculated_host_listings_count_private_rooms  \
# 6798                                            2
# 829                                             0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 6798                                           0              3.49
# 829                                            0              0.45
#
# [2 rows x 75 columns]
